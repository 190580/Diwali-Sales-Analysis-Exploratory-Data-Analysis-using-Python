# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv(r"C:\Users\amal\anaconda3\Lib\site-packages\bokeh\sampledata\_data\iris.csv")

# %%
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# data visualisation

# %%
iris.plot(kind="scatter",x="sepal_length",y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data_set,hue="species",height=5)\
   .map(plt.scatter,"sepal_length","sepal_width")\
   .add_legend()

plt.show();

# %%
sns.set_style("whitegrid")
sns.pairplot(data_set,hue="species",height=3);

# %% [markdown]
# Observations
#
# -petal_length and petal_width are two most useful features in identifying the various flower types
# -Setossa can be easily identified ,virginica and versicolor have some overlap
#
# Limitation
#
# -pair plots are easy to understand when we have little number of features

# %%
iris_setosa = iris.loc[iris["species"].str.strip().str.lower() == "setosa"]
iris_virginica = iris.loc[iris["species"].str.strip().str.lower() == "virginica"]
iris_versicolor = iris.loc[iris["species"].str.strip().str.lower() == "versicolor"]

plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa["petal_length"]))
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_virginica["petal_length"]))
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor["petal_length"]))

# %%
#density plot of petal length of all flowers

sns.FacetGrid(iris, hue="species",height=5)\
   .map(sns.distplot, "petal_length")\
   .add_legend()

plt.show()
# Out:
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species",height=5)\
   .map(sns.distplot, "petal_width")\
   .add_legend()

plt.show()
# Out:
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species",height=5)\
   .map(sns.distplot, "sepal_width")\
   .add_legend()

plt.show()
# Out:
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species",height=5)\
   .map(sns.distplot, "sepal_length")\
   .add_legend()

plt.show()
# Out:
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\amal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# observations
#
# -after plotting all the features, petal_length is the best performing in seperating each features
#
# -if we want to use simple feature to seperate we can use petal_length
#
# -if we want to use two features for seperating we can use petal_length and petal_width
#
# -petal_length>petal_width>sepal_length>sepal_width

# %%
#setosa

counts, bin_edges = np.histogram(iris_setosa["petal_length"],bins =10,
                                  density = True)
#compute pdf

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

#cdf
cdf= np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.title("iris_setosa")


#virginica

counts, bin_edges = np.histogram(iris_virginica["petal_length"],bins =10,
                                  density = True)
#compute pdf

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

#cdf
cdf= np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)



#versiculor

counts, bin_edges = np.histogram(iris_versicolor["petal_length"],bins =10,
                                  density = True)
#compute pdf

pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

#cdf
cdf= np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.title("iris_versicolor")
plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# observations
#
# -pdf and cdf for setosa, versicolor, virginica with respect to petal length
#
# -if pl <2  then setosa  100% accurate
#
# -if pl >2 and <=5 versicular 95 %times correct and 5 % times incorrect
#
# -if pl >4.5 virginica 90 %correct and 10 % incorrect

# %%
#means 
print("means")
print("setosa :" , np.mean(iris_setosa["petal_length"]))
print("versicolor :" , np.mean(iris_setosa["petal_length"]))
print("virginica :" , np.mean(iris_setosa["petal_length"]))

#standard deviation
print("\nstd-dev")
print("setosa :" , np.std(iris_setosa["petal_length"]))
print("versicolor :" , np.std(iris_setosa["petal_length"]))
print("virginica :" , np.std(iris_setosa["petal_length"]))
# Out:
# means
# setosa : 1.4620000000000002
# versicolor : 1.4620000000000002
# virginica : 1.4620000000000002
#
# std-dev
# setosa : 0.17191858538273286
# versicolor : 0.17191858538273286
# virginica : 0.17191858538273286
